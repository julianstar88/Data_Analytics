# %%
import spacy
from pathlib import Path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
config_path = Path("/content/drive/MyDrive/spacy/spacy_config")
train_path = Path(r"/content/drive/MyDrive/spacy/spacy_train")
output_path = Path(r"/content/drive/MyDrive/spacy/spacy_model")

train_file = "train.spacy"
dev_file = "dev.spacy"
config_file = "config.cfg"

# !python -m spacy train {config_path/config_file} --paths.train {train_path/train_file} --paths.dev {train_path/dev_file} --output {output_path} --verbose
# Out:
# [2024-06-19 10:16:23,293] [DEBUG] Config overrides from CLI: ['paths.train', 'paths.dev']
# ℹ Saving to output directory:
# /content/drive/MyDrive/spacy/spacy_model
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# [2024-06-19 10:16:24,238] [INFO] Set up nlp object from config
# [2024-06-19 10:16:24,271] [DEBUG] Loading corpus from path: /content/drive/MyDrive/spacy/spacy_train/dev.spacy
# [2024-06-19 10:16:24,275] [DEBUG] Loading corpus from path: /content/drive/MyDrive/spacy/spacy_train/train.spacy
# [2024-06-19 10:16:24,275] [INFO] Pipeline: ['textcat']
# [2024-06-19 10:16:24,281] [INFO] Created vocabulary
# [2024-06-19 10:16:24,282] [INFO] Finished initializing nlp object
# [2024-06-19 10:17:44,203] [INFO] Initialized pipeline components: ['textcat']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ...
